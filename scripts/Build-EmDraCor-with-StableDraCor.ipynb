# %% [markdown]
# ## 1. Creating a Dockerized dracor platform

# %%
import logging
logging.basicConfig(level=logging.DEBUG)
# logging.basicConfig(level=logging.INFO)

# %%
# from client.client import api_get

# %%
#api_get(method="corpora", api_base_url="http://localhost:8088/api/")
# api_get(method="corpora")

# %%
from stabledracor.client import StableDraCor
dracor = StableDraCor()
dracor.run()

# %%
local_api.services
# Out:
# {'api': None, 'frontend': None, 'metrics': None, 'triplestore': None}

# %%
local_api.run(compose_file="configurations/compose.fullstack.empty.yml")
# Out:
# DEBUG:root:Started with docker compose file configurations/compose.fullstack.empty.yml
# DEBUG:root:Detected 4 running Docker containers.
# INFO:root:Found dracor/dracor-api container with ID 4a466e0808f7. Image is: dracor/dracor-api:v0.90.1-local
# INFO:root:Found dracor/dracor-frontend container with ID b6cfb61f2eb9. Image is: dracor/dracor-frontend:v1.6.0-dirty
# INFO:root:Found dracor/dracor-metrics container with ID d6fb33ff8c1d. Image is: dracor/dracor-metrics:v1.2.0
# INFO:root:Found dracor/dracor-fuseki container with ID fbc8b420da35. Image is: dracor/dracor-fuseki:v1.0.0

# %%
local_api.services
# Out:
# {'api': {'container': '4a466e0808f7',
#   'image': 'dracor/dracor-api:v0.90.1-local'},
#  'frontend': {'container': 'b6cfb61f2eb9',
#   'image': 'dracor/dracor-frontend:v1.6.0-dirty'},
#  'metrics': {'container': 'd6fb33ff8c1d',
#   'image': 'dracor/dracor-metrics:v1.2.0'},
#  'triplestore': {'container': 'fbc8b420da35',
#   'image': 'dracor/dracor-fuseki:v1.0.0'}}

# %%
local_api.stop()
# Out:
# DEBUG:root:Stopping all services.
# INFO:root:Stopped container '4a466e0808f7'.
# INFO:root:Stopped container 'b6cfb61f2eb9'.
# INFO:root:Stopped container 'd6fb33ff8c1d'.
# INFO:root:Stopped container 'fbc8b420da35'.

# %%
local_api.create_compose_file()
# Out:
# INFO:root:Stored configuration (docker-compose file) as compose.my-stable-dracor.yml.

# %% [markdown]
# At this point, an empty DraCor architecture should have been created. Check at [localhost://8088](https://localhost://8088)!

# %% [markdown]
# ## 2. Load plays from own Github repo

# %%
dracor.add_corpus_from_repo(repository_owner="lucagiovannini7", repository_name="emdracor")

# %%
# grab plays from github with pygithub or similar library
# since for me it often doesn't work, I stored all link in a file and in the following cell

# %%
clean_urls = ['https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-dracor/gryphius-absurda-comica-oder-herr-peter-squentz.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-dracor/gryphius-cardenio-und-celinde.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-dracor/reuter-der-ehrlichen-frau-schlampampe-krankheit-und-tod.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-dracor/weise-masaniello.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/anonym-lustig-pickelherings-spiel.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/anonym-macht-kleines-knaben.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/braunschweig-fleischhawer.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/braunschweig-ungeratenen-sohn.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/feinde-verwirrte-haus-jacob.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/frischlin-fraw-wendelgard.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/hallmann-liberata.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/hallmann-sophia.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/hayneccius-hans-pfriem.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/hollonius-somnium-vitae-humanae.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/krueger-anfang-ende-welt.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/lohenstein-epicharis.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/lohenstein-ibrahim.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/mitternacht-unglueckselige-soldat.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/murer-absolom.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/murer-esther.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/opitz-judith.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/rinckart-eislebische-ritter.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/rist-irenaromachia.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/rist-perseus.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/rollenhagen-reichen-mann.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/schlue-isaac.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/schoch-comoedia-studenten.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/stranitzky-tuerckisch-bestraffter-hochmuth.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/de-local/weise-baeurischer-machiavellus.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls
xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/it-local/memmolo-susanna.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/it-local/nolfi-romilda.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/it-local/oransi-rosina.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/it-local/riccoboni-tito-manlio.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/it-local/salviati-granchio.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/it-local/testi-isola-alcina.xml',
 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/main/dracor-xmls/it-local/tortoletti-gionata.xml']

# %%
#count plays, they should be 150
print(len(clean_urls))
# Out:
# 150

# %%
# add the commit id inside the url (optional, for reproducibility)
'''
new_urls = []
for url in clean_urls:
  url = url.replace("main", #number_of_latest_commit)
print(new_urls)
'''
# Out:
# ['https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/0df8cb425031590c0c860cb40349b23d5d1080ab/dracor-xmls/xmlformat.pl', 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/5f223933e7ed5c2f3ed3d8b116afef7a1638d965/dracor-xmls/de/DEU01-murer-absolom.xml', 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/5f223933e7ed5c2f3ed3d8b116afef7a1638d965/dracor-xmls/de/DEU02-murer-esther.xml', 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/5f223933e7ed5c2f3ed3d8b116afef7a1638d965/dracor-xmls/de/DEU03-frischlin-fraw-wendelgard.xml', 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/5f223933e7ed5c2f3ed3d8b116afef7a1638d965/dracor-xmls/de/DEU04-krueger-anfang-ende-welt.xml', 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/5f223933e7ed5c2f3ed3d8b116afef7a1638d965/dracor-xmls/de/DEU05-hayneccius-hans-pfriem.xml', 'https://raw.githubusercontent.com/lucagiovannini7/baroque-networks/5f223933e7ed
# ...

# %%
# if pygithub is not working on jupyter notebook, use the links stored here
'''
url = 'https://github.com/lucagiovannini7/baroque-networks/...'
links = requests.get(url)
'''

# %% [markdown]
# ### Iterate over list of URLs to add them to the corpus

# %%
# testing 'playname' construction
for url in clean_urls:
    r = requests.get(url)
    #get only the text from the response and encode it in UTF-8 (important!)
    tei = r.text.encode('utf-8')
    playname = url[93:].split(".xml")[0]
    playname = playname.replace('/','')
    print(playname)
# Out:
# 'hayneccius-hans-pfriem'

# %%
# load all plays
counter = 1
for url in clean_urls:
    r = requests.get(url)
    #get only the text from the response and encode it in UTF-8 (important!)
    tei = r.text.encode('utf-8')
    playname = url[93:].split(".xml")[0]
    playname = playname.replace('/','')
    #print("Processing", playname)
    #construct the URL to use in the PUT request:
    put_request_url = "http://localhost:8088/api/corpora/" + "em" + "/play/" + playname + "/tei"
    print("Loading", put_request_url, ". Processed: ", counter, "/150")
    counter += 1
    headers = {'Content-Type': 'application/xml'}
    #loads play
    r = requests.put(put_request_url, data=tei, headers=headers, auth=HTTPBasicAuth(usr, pwd))

# %%
local_api.add_corpus_from_repo(repository_name="bashdracor")

# %%
local_api.create_docker_image_of_service(service="api", image_tag="my_local_bashdracor")
# Out:
# DEBUG:root:Creating image of service 'api'.
# DEBUG:root:Container 4a466e0808f7 is in state: exited.
# INFO:root:Committed container 4a466e0808f7 as dracor/stable-dracor:my_local_bashdracor. Image identifier sha256:bc473e063c4aca40697990b02ee2dcaa629a7e525d62fe96aa583183ec0d3320
# .
# DEBUG:root:Updated services. Image dracor/stable-dracor:my_local_bashdracor is set as service 'api'.

# %%
local_api.services
# Out:
# {'api': {'container': '4a466e0808f7',
#   'image': 'dracor/stable-dracor:my_local_bashdracor'},
#  'frontend': {'container': 'b6cfb61f2eb9',
#   'image': 'dracor/dracor-frontend:v1.6.0-dirty'},
#  'metrics': {'container': 'd6fb33ff8c1d',
#   'image': 'dracor/dracor-metrics:v1.2.0'},
#  'triplestore': {'container': 'fbc8b420da35',
#   'image': 'dracor/dracor-fuseki:v1.0.0'}}

# %%
local_api.create_compose_file(file_name="compose.bashdracor.yml")
# Out:
# INFO:root:Stored configuration (docker-compose file) as compose.bashdracor.yml.

# %%
# Shutting down containers with Docker Desktop, deleting the containers

# %%
# local_api = StableDraCor()
local_bashdracor = StableDraCor(name="local_bashdracor", description="Local stack with BashDraCor pre-loaded")

# %%
local_bashdracor.services

# %%
local_bashdracor.run(compose_file="compose.bashdracor.yml")

# %%
local_bashdracor.services

# %%
local_bashdracor.list_docker_containers()

# %%
# compose.my-stable-dracor.yml

# %%
#List available Docker images
#images = local_api.list_docker_images()
#images

# %%
import os
dockerhub_user = os.environ.get("DOCKERHUB_USER")
dockerhub_password = os.environ.get("DOCKERHUB_PASSWORD")

# %%
local_api.publish_docker_image(user=dockerhub_user, password=dockerhub_password)

# %%
#containers = local_api.list_docker_containers()
#containers

# %%
#containers = local_api.list_docker_containers(only_running=True)
#containers

# %%
#local_api.run()

# %%
# local_api.id

# %%
# Copy a corpus from the dracor production instance at dracor.org
# local_api.copy_corpus(source_corpusname="bash")

# %%
#local_api.remove_corpus(corpusname="tat")

# %%
# local_api.remove_corpus(corpusname="gersh")

# %%
#local_api.copy_corpus(source_corpusname="gersh")

# %%
# try to delete "gersh/ein-sommernachtstraum":
#local_api.remove_play_from_corpus(corpusname="gersh", playname="ein-sommernachtstraum")

# %%
#include bash, but not /bash/khudayberdin-aq-bilettar, bash/karim-aj-totolghan-tonda
#local_api.copy_corpus(source_corpusname="bash", exclude=["khudayberdin-aq-bilettar","karim-aj-totolghan-tonda"])

# %%
# delte karim-tashlama-utty
#local_api.remove_play_from_corpus(corpusname="bash", playname="karim-tashlama-utty")

# %%
#local_api.remove_corpus(corpusname="bash")

# %%
# Remove a single corpus, e.g. the corpus custom
# local_api.remove_corpus(corpusname="custom")

# %%
"""
imported_corpus_metadata = {
    "name" : "custom",
    "title": "My Custom Corpus",
    "description": "This is a custom corpus that was generated with the 'StableDraCor' client. It contains files from a local directory."
}
local_api.add_plays_from_directory(corpusname="custom",directory="test_import_dir", corpus_metadata=imported_corpus_metadata)
"""

# %%
"""
filename="grillparzer-des-meeres-und-der-liebe-wellen"
commit="d23a93d9fa0e4eb53a580904ac5d01c8b8f8037c"
repository_name = "gerdracor"
local_api.add_play_version_to_corpus(filename=filename, commit=commit,repository_name=repository_name, corpusname="gittest")
"""

# %%
# if commit is not set, will use latest version
"""
filename="lessing-emilia-galotti"
repository_name = "gerdracor"
local_api.add_play_version_to_corpus(filename=filename,repository_name=repository_name, corpusname="latestlessing")
"""

# %%
# local_api.list_plays_in_repo(repository_name="gerdracor")

# %%
# local_api.list_plays_in_repo(repository_name="rusdracor")

# %%
#local_api.list_plays_in_repo(repository_name="spandracor")

# %%
#Gerdracor @ 2019-04-05
#print("GerDraCor commit from 2019-04-05 – Number of plays in repo: ")
#print(len(local_api.list_plays_in_repo(repository_name="gerdracor", commit="59df6c5bcdd5377cd6c2700777ab1b88e094b9b6")))
# vs current dracor
#print("Current state of GerDraCor:")
#print(len(local_api.list_plays_in_repo(repository_name="gerdracor")))

# %%
# local_api.add_corpus_from_repo(repository_name="tatdracor")

# %%
#local_api.add_corpus_from_repo(repository_name="bashdracor")
